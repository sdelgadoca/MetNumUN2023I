# %% [markdown]
# <a href="https://colab.research.google.com/github/gjhernandezp/NM/blob/main/SymPyLab/SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (x - 17)(x - 19)(x - 67)(x - 2)(x + 3)(x + 5)(x - 11)(x + 23)(x - 29)(x - 31) = -147665415810 + 30599050463 x + 27835595545 x^2 - 2216143436 x^3 - 602089600 x^4 + 83547498 x^5 - 2784834 x^6 - 73580 x^7 + 6698 x^8 - 145 x^9 + x^10
#
# - -147665415810 + 30599050463 x + 27835595545 x^2 - 2216143436 x^3 - 602089600 x^4 + 83547498 x^5 - 2784834 x^6 - 73580 x^7 + 6698 x^8 - 145 x^9 + x^10 / (x + 17) = 8686200930 - 1288991149 x - 1713210982 x^2 + 29584262 x^3 + 37157286 x^4 - 2728836 x^5 + 3294 x^6 + 4522 x^7 - 128 x^8 + x^9

# %% [markdown]
# ![polinomio.png](data:image/png;base64,...)

# %% [markdown]
# ![poli2.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')


p = x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810

p, r = div(p,  x - 17)

print(p)
print(r)

p, r = div(p,  x - 19)

print(p)
print(r)

p, r = div(p,  x - 67)

print(p)
print(r)

p, r = div(p,  x - 2)

print(p)
print(r)

p, r = div(p,  x + 3)

print(p)
print(r)


p, r = div(p,  x + 5)

print(p)
print(r)


p, r = div(p,  x - 11)

print(p)
print(r)


p, r = div(p,  x + 23)

print(p)
print(r)

p, r = div(p, x - 29)

print(p)
print(r)

p, r = div(p, x - 31)

print(p)
print(r)
# Out:
# x**9 - 128*x**8 + 4522*x**7 + 3294*x**6 - 2728836*x**5 + 37157286*x**4 + 29584262*x**3 - 1713210982*x**2 - 1288991149*x + 8686200930
# 0
# x**8 - 109*x**7 + 2451*x**6 + 49863*x**5 - 1781439*x**4 + 3309945*x**3 + 92473217*x**2 + 43780141*x - 457168470
# 0
# x**7 - 42*x**6 - 363*x**5 + 25542*x**4 - 70125*x**3 - 1388430*x**2 - 551593*x + 6823410
# 0
# x**6 - 40*x**5 - 443*x**4 + 24656*x**3 - 20813*x**2 - 1430056*x - 3411705
# 0
# x**5 - 43*x**4 - 314*x**3 + 25598*x**2 - 97607*x - 1137235
# 0
# x**4 - 48*x**3 - 74*x**2 + 25968*x - 227447
# 0
# x**3 - 37*x**2 - 481*x + 20677
# 0
# x**2 - 60*x + 899
# 0
# x - 31
# 0
# 1
# 0

# %%
p = x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810

p, r = div(p,  x+2)

print(p)
print(r)
# Out:
# x**9 - 147*x**8 + 6992*x**7 - 87564*x**6 - 2609706*x**5 + 88766910*x**4 - 779623420*x**3 - 656896596*x**2 + 29149388737*x - 27699727011
# -92265961788

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(-147665415810 + 30599050463 x + 27835595545 x^2 - 2216143436 x^3 - 602089600 x^4 + 83547498 x^5 - 2784834 x^6 - 73580 x^7 + 6698 x^8 - 145 x^9 + x^10)

# %% [markdown]
# ![factor.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810)
# Out:
# (x - 67)*(x - 31)*(x - 29)*(x - 19)*(x - 17)*(x - 11)*(x - 2)*(x + 3)*(x + 5)*(x + 23)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - -147665415810 + 30599050463 x + 27835595545 x^2 - 2216143436 x^3 - 602089600 x^4 + 83547498 x^5 - 2784834 x^6 - 73580 x^7 + 6698 x^8 - 145 x^9 + x^10 = 0

# %% [markdown]
# ![solve.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810), x)
# Out:
# <ipython-input-21-4b337c683db5>:3: SymPyDeprecationWarning:
#
# Eq(expr) with a single argument with the right-hand side
# defaulting to 0 is deprecated. Use Eq(expr, 0) instead.
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#deprecated-eq-expr
# for details.
#
# This has been deprecated since SymPy version 1.5. It
# will be removed in a future version of SymPy.
#
#   solveset(Eq(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810), x)
# {-23, -5, -3, 2, 11, 17, 19, 29, 31, 67}

# %% [markdown]
# ![parabola.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq((1/4)*pi*(2*x**2 - 1) + 3*x , 0), x)
# Out:
# {-3.0/pi + 3.0*sqrt(0.0555555555555556*pi**2 + 1.0)/pi, -3.0*sqrt(0.0555555555555556*pi**2 + 1.0)/pi - 3.0/pi}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![modulo.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810,domain='GF(2)')
# Out:
# x*(x + 1)**9

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# ![expand.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = 17*x1 + I*x2
y = 19*y1 + I*y2
z = 67*z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (17*x1 + I*x2)*(19*y1 + I*y2)*(67*z1 + I*z2)
# 21641*x1*y1*z1 + 323*I*x1*y1*z2 + 1139*I*x1*y2*z1 - 17*x1*y2*z2 + 1273*I*x2*y1*z1 - 19*x2*y1*z2 - 67*x2*y2*z1 - I*x2*y2*z2
# 21641*x1*y1*z1 + 323*I*x1*y1*z2 + 1139*I*x1*y2*z1 - 17*x1*y2*z2 + 1273*I*x2*y1*z1 - 19*x2*y1*z2 - 67*x2*y2*z1 - I*x2*y2*z2
# 21641*x1*y1*z1 + 323*I*x1*y1*z2 + 1139*I*x1*y2*z1 - 17*x1*y2*z2 + 1273*I*x2*y1*z1 - 19*x2*y1*z2 - 67*x2*y2*z1 - I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the distance to the nearest star?
#
# ![sun.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![centauri.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![integral.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810, x)
# Out:
# x**11/11 - 29*x**10/2 + 6698*x**9/9 - 18395*x**8/2 - 2784834*x**7/7 + 13924583*x**6 - 120417920*x**5 - 554035859*x**4 + 27835595545*x**3/3 + 30599050463*x**2/2 - 147665415810*x

# %% [markdown]
# ![definida.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810, (x,1,5))
# Out:
# 269827804217344/693

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**10 - 145*x**9  + 6698*x**8 - 73580*x**7 - 2784834*x**6 + 83547498*x**5 - 602089600*x**4 - 2216143436*x**3 + 27835595545*x**2 + 30599050463*x*1 - 147665415810, (x,1,5)))
# Out:
# 389361910847.538
