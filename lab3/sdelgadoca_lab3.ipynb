# %% [markdown]
# laboratorio 3 certificados

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/e7b5db3b7b92468995503a7d3a471a74

# %% [markdown]
# ![imagen_2023-03-08_123037208.png](data:image/png;base64,...)

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/fea1590214cb4f2d8e472436b7ed144f

# %% [markdown]
# ![imagen_2023-03-08_123103394.png](data:image/png;base64,...)

# %% [markdown]
# https://courses.cognitiveclass.ai/certificates/ee74056788b74fd4bf58f167a57c26c4

# %% [markdown]
# ![imagen_2023-03-08_123128672.png](data:image/png;base64,...)

# %% [markdown]
# Linkedin
#
# https://www.linkedin.com/in/sebastian-delgado-cabrera-6bbb3b268/

# %% [markdown]
# ![imagen_2023-03-09_113601489.png](data:image/png;base64,...)
